# %%
# !pip install textstat
# !pip install lftk
# !pip install spacy
# !pip install evaluate
# !pip install datasets
# !pip install accelerate -U
# !pip install transformers[torch]
# Out:
# Requirement already satisfied: textstat in /usr/local/lib/python3.10/dist-packages (0.7.3)
# Requirement already satisfied: pyphen in /usr/local/lib/python3.10/dist-packages (from textstat) (0.15.0)
# Requirement already satisfied: lftk in /usr/local/lib/python3.10/dist-packages (1.0.9)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from lftk) (2.0.3)
# Requirement already satisfied: ndjson in /usr/local/lib/python3.10/dist-packages (from lftk) (0.3.1)
# Requirement already satisfied: spacy in /usr/local/lib/python3.10/dist-packages (from lftk) (3.7.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->lftk) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->lftk) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas->lftk) (2024.1)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from pandas->lftk) (1.25.2)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.10/dist-packages (from spacy->lftk) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from spacy->lftk) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.10/dist-packages (from spacy->lftk) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy->lftk) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy->lftk) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.2.2 in /usr/local/lib/python3.10/dist-packages (from spacy->lftk) (8.2.3)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.10/dist-packages (from spacy->lftk) (1.1.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.10/dist-packages (from spacy->lftk) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.10/dist-packages (from spacy->lftk) (2.0.10)
# Requirement already satisfied: weasel<0.4.0,>=0.1.0 in /usr/local/lib/python3.10/dist-packages (from spacy->lftk) (0.3.4)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from spacy->lftk) (0.9.4)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /usr/local/lib/python3.10/dist-packages (from spacy->lftk) (6.4.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.10/dist-packages (from spacy->lftk) (4.66.4)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from spacy->lftk) (2.31.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /usr/local/lib/python3.10/dist-packages (from spacy->lftk) (2.7.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from spacy->lftk) (3.1.4)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from spacy->lftk) (67.7.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from spacy->lftk) (24.0)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.10/dist-packages (from spacy->lftk) (3.4.0)
# Requirement already satisfied: language-data>=1.2 in /usr/local/lib/python3.10/dist-packages (from langcodes<4.0.0,>=3.2.0->spacy->lftk) (1.2.0)
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy->lftk) (0.6.0)
# Requirement already satisfied: pydantic-core==2.18.2 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy->lftk) (2.18.2)
# Requirement already satisfied: typing-extensions>=4.6.1 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy->lftk) (4.11.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas->lftk) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy->lftk) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy->lftk) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy->lftk) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy->lftk) (2024.2.2)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.10/dist-packages (from thinc<8.3.0,>=8.2.2->spacy->lftk) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.10/dist-packages (from thinc<8.3.0,>=8.2.2->spacy->lftk) (0.1.4)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /usr/local/lib/python3.10/dist-packages (from typer<0.10.0,>=0.3.0->spacy->lftk) (8.1.7)
# Requirement already satisfied: cloudpathlib<0.17.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from weasel<0.4.0,>=0.1.0->spacy->lftk) (0.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->spacy->lftk) (2.1.5)
# Requirement already satisfied: marisa-trie>=0.7.7 in /usr/local/lib/python3.10/dist-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy->lftk) (1.1.1)
# Requirement already satisfied: spacy in /usr/local/lib/python3.10/dist-packages (3.7.4)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.10/dist-packages (from spacy) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.2.2 in /usr/local/lib/python3.10/dist-packages (from spacy) (8.2.3)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.10/dist-packages (from spacy) (1.1.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.10/dist-packages (from spacy) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.10/dist-packages (from spacy) (2.0.10)
# Requirement already satisfied: weasel<0.4.0,>=0.1.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (0.3.4)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (0.9.4)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /usr/local/lib/python3.10/dist-packages (from spacy) (6.4.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (4.66.4)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (2.31.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /usr/local/lib/python3.10/dist-packages (from spacy) (2.7.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from spacy) (3.1.4)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from spacy) (67.7.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (24.0)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (3.4.0)
# Requirement already satisfied: numpy>=1.19.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (1.25.2)
# Requirement already satisfied: language-data>=1.2 in /usr/local/lib/python3.10/dist-packages (from langcodes<4.0.0,>=3.2.0->spacy) (1.2.0)
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (0.6.0)
# Requirement already satisfied: pydantic-core==2.18.2 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (2.18.2)
# Requirement already satisfied: typing-extensions>=4.6.1 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (4.11.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (2024.2.2)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.10/dist-packages (from thinc<8.3.0,>=8.2.2->spacy) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.10/dist-packages (from thinc<8.3.0,>=8.2.2->spacy) (0.1.4)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /usr/local/lib/python3.10/dist-packages (from typer<0.10.0,>=0.3.0->spacy) (8.1.7)
# Requirement already satisfied: cloudpathlib<0.17.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from weasel<0.4.0,>=0.1.0->spacy) (0.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->spacy) (2.1.5)
# Requirement already satisfied: marisa-trie>=0.7.7 in /usr/local/lib/python3.10/dist-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy) (1.1.1)
# Requirement already satisfied: evaluate in /usr/local/lib/python3.10/dist-packages (0.4.2)
# Requirement already satisfied: datasets>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from evaluate) (2.19.1)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from evaluate) (1.25.2)
# Requirement already satisfied: dill in /usr/local/lib/python3.10/dist-packages (from evaluate) (0.3.8)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from evaluate) (2.0.3)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.10/dist-packages (from evaluate) (2.31.0)
# Requirement already satisfied: tqdm>=4.62.1 in /usr/local/lib/python3.10/dist-packages (from evaluate) (4.66.4)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.10/dist-packages (from evaluate) (3.4.1)
# Requirement already satisfied: multiprocess in /usr/local/lib/python3.10/dist-packages (from evaluate) (0.70.16)
# Requirement already satisfied: fsspec[http]>=2021.05.0 in /usr/local/lib/python3.10/dist-packages (from evaluate) (2023.6.0)
# Requirement already satisfied: huggingface-hub>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from evaluate) (0.23.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from evaluate) (24.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from datasets>=2.0.0->evaluate) (3.14.0)
# Requirement already satisfied: pyarrow>=12.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets>=2.0.0->evaluate) (14.0.2)
# Requirement already satisfied: pyarrow-hotfix in /usr/local/lib/python3.10/dist-packages (from datasets>=2.0.0->evaluate) (0.6)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets>=2.0.0->evaluate) (3.9.5)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from datasets>=2.0.0->evaluate) (6.0.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.7.0->evaluate) (4.11.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->evaluate) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->evaluate) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->evaluate) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->evaluate) (2024.2.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->evaluate) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->evaluate) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas->evaluate) (2024.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.0.0->evaluate) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.0.0->evaluate) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.0.0->evaluate) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.0.0->evaluate) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.0.0->evaluate) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.0.0->evaluate) (4.0.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas->evaluate) (1.16.0)
# Requirement already satisfied: datasets in /usr/local/lib/python3.10/dist-packages (2.19.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from datasets) (3.14.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from datasets) (1.25.2)
# Requirement already satisfied: pyarrow>=12.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (14.0.2)
# Requirement already satisfied: pyarrow-hotfix in /usr/local/lib/python3.10/dist-packages (from datasets) (0.6)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (0.3.8)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datasets) (2.0.3)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (2.31.0)
# Requirement already satisfied: tqdm>=4.62.1 in /usr/local/lib/python3.10/dist-packages (from datasets) (4.66.4)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.10/dist-packages (from datasets) (3.4.1)
# Requirement already satisfied: multiprocess in /usr/local/lib/python3.10/dist-packages (from datasets) (0.70.16)
# Requirement already satisfied: fsspec[http]<=2024.3.1,>=2023.1.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (2023.6.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets) (3.9.5)
# Requirement already satisfied: huggingface-hub>=0.21.2 in /usr/local/lib/python3.10/dist-packages (from datasets) (0.23.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from datasets) (24.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from datasets) (6.0.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (4.0.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.21.2->datasets) (4.11.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets) (2024.2.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2024.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.16.0)
# Requirement already satisfied: accelerate in /usr/local/lib/python3.10/dist-packages (0.30.1)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from accelerate) (1.25.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from accelerate) (24.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from accelerate) (5.9.5)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from accelerate) (6.0.1)
# Requirement already satisfied: torch>=1.10.0 in /usr/local/lib/python3.10/dist-packages (from accelerate) (2.3.0+cu121)
# Requirement already satisfied: huggingface-hub in /usr/local/lib/python3.10/dist-packages (from accelerate) (0.23.0)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from accelerate) (0.4.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (3.14.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (4.11.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (2023.6.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.20.5 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (2.20.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (12.1.105)
# Requirement already satisfied: triton==2.3.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (2.3.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /usr/local/lib/python3.10/dist-packages (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.10.0->accelerate) (12.5.40)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface-hub->accelerate) (2.31.0)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub->accelerate) (4.66.4)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.10.0->accelerate) (2.1.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->accelerate) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->accelerate) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->accelerate) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->accelerate) (2024.2.2)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.10.0->accelerate) (1.3.0)
# Requirement already satisfied: transformers[torch] in /usr/local/lib/python3.10/dist-packages (4.41.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers[torch]) (3.14.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from transformers[torch]) (0.23.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers[torch]) (1.25.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers[torch]) (24.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers[torch]) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers[torch]) (2023.12.25)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers[torch]) (2.31.0)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /usr/local/lib/python3.10/dist-packages (from transformers[torch]) (0.19.1)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers[torch]) (0.4.3)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers[torch]) (4.66.4)
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (from transformers[torch]) (2.3.0+cu121)
# Requirement already satisfied: accelerate>=0.21.0 in /usr/local/lib/python3.10/dist-packages (from transformers[torch]) (0.30.1)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from accelerate>=0.21.0->transformers[torch]) (5.9.5)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.23.0->transformers[torch]) (2023.6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.23.0->transformers[torch]) (4.11.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch->transformers[torch]) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch->transformers[torch]) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch->transformers[torch]) (3.1.4)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch->transformers[torch]) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch->transformers[torch]) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch->transformers[torch]) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /usr/local/lib/python3.10/dist-packages (from torch->transformers[torch]) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /usr/local/lib/python3.10/dist-packages (from torch->transformers[torch]) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /usr/local/lib/python3.10/dist-packages (from torch->transformers[torch]) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /usr/local/lib/python3.10/dist-packages (from torch->transformers[torch]) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /usr/local/lib/python3.10/dist-packages (from torch->transformers[torch]) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /usr/local/lib/python3.10/dist-packages (from torch->transformers[torch]) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.20.5 in /usr/local/lib/python3.10/dist-packages (from torch->transformers[torch]) (2.20.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch->transformers[torch]) (12.1.105)
# Requirement already satisfied: triton==2.3.0 in /usr/local/lib/python3.10/dist-packages (from torch->transformers[torch]) (2.3.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /usr/local/lib/python3.10/dist-packages (from nvidia-cusolver-cu12==11.4.5.107->torch->transformers[torch]) (12.5.40)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers[torch]) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers[torch]) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers[torch]) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers[torch]) (2024.2.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch->transformers[torch]) (2.1.5)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch->transformers[torch]) (1.3.0)

# %%
# !python -m spacy download en_core_web_sm
# Out:
# Collecting en-core-web-sm==3.7.1
#   Using cached https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.7.1/en_core_web_sm-3.7.1-py3-none-any.whl (12.8 MB)
# Requirement already satisfied: spacy<3.8.0,>=3.7.2 in /usr/local/lib/python3.10/dist-packages (from en-core-web-sm==3.7.1) (3.7.4)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.2.2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (8.2.3)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.1.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.0.10)
# Requirement already satisfied: weasel<0.4.0,>=0.1.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.3.4)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.9.4)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (6.4.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (4.66.4)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.31.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.7.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.1.4)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (67.7.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (24.0)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.4.0)
# Requirement already satisfied: numpy>=1.19.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.25.2)
# Requirement already satisfied: language-data>=1.2 in /usr/local/lib/python3.10/dist-packages (from langcodes<4.0.0,>=3.2.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.2.0)
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.6.0)
# Requirement already satisfied: pydantic-core==2.18.2 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.18.2)
# Requirement already satisfied: typing-extensions>=4.6.1 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (4.11.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2024.2.2)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.10/dist-packages (from thinc<8.3.0,>=8.2.2->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.10/dist-packages (from thinc<8.3.0,>=8.2.2->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.1.4)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /usr/local/lib/python3.10/dist-packages (from typer<0.10.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (8.1.7)
# Requirement already satisfied: cloudpathlib<0.17.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from weasel<0.4.0,>=0.1.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.1.5)
# Requirement already satisfied: marisa-trie>=0.7.7 in /usr/local/lib/python3.10/dist-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.1.1)
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')
# ⚠ Restart to reload dependencies
# If you are in a Jupyter or Colab notebook, you may need to restart Python in
# order to load all the package's dependencies. You can do this by selecting the
# 'Restart kernel' or 'Restart runtime' option.

# %%
# !pip install -U sentence-transformers
# Out:
# Collecting sentence-transformers
#   Downloading sentence_transformers-2.7.0-py3-none-any.whl (171 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 171.5/171.5 kB 3.3 MB/s eta 0:00:00
# Requirement already satisfied: transformers<5.0.0,>=4.34.0 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (4.41.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (4.66.4)
# Requirement already satisfied: torch>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (2.3.0+cu121)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (1.25.2)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (1.2.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (1.11.4)
# Requirement already satisfied: huggingface-hub>=0.15.1 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (0.23.0)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (9.4.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.15.1->sentence-transformers) (3.14.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.15.1->sentence-transformers) (2023.6.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.15.1->sentence-transformers) (24.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.15.1->sentence-transformers) (6.0.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.15.1->sentence-transformers) (2.31.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.15.1->sentence-transformers) (4.11.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers) (3.1.4)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.20.5 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers) (2.20.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers) (12.1.105)
# Requirement already satisfied: triton==2.3.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers) (2.3.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /usr/local/lib/python3.10/dist-packages (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.11.0->sentence-transformers) (12.5.40)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.34.0->sentence-transformers) (2023.12.25)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.34.0->sentence-transformers) (0.19.1)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.34.0->sentence-transformers) (0.4.3)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->sentence-transformers) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->sentence-transformers) (3.5.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.11.0->sentence-transformers) (2.1.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.15.1->sentence-transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.15.1->sentence-transformers) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.15.1->sentence-transformers) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.15.1->sentence-transformers) (2024.2.2)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.11.0->sentence-transformers) (1.3.0)
# Installing collected packages: sentence-transformers
# Successfully installed sentence-transformers-2.7.0

# %%
import spacy
import lftk
import transformers
import textstat
import torch
import pandas as pd
import accelerate
from evaluate import load
import evaluate
from datasets import load_metric
import xgboost as xgb
import numpy as np
import re, statistics, string
import matplotlib.pyplot as plt
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.model_selection import cross_validate
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.metrics import accuracy_score, f1_score
from collections import Counter
import nltk
from nltk.util import ngrams
from sentence_transformers import SentenceTransformer
from transformers import AutoTokenizer, AutoModel
nltk.download('punkt')
from nltk.tokenize import word_tokenize
np.random.seed(0)
# %matplotlib inline
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
bert_tokenizer = AutoTokenizer.from_pretrained("bert-base-cased")
bert_model = AutoModel.from_pretrained("bert-base-cased")
# Out:
# tokenizer_config.json:   0%|          | 0.00/49.0 [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# config.json:   0%|          | 0.00/570 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/213k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/436k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/436M [00:00<?, ?B/s]

# %% [markdown]
# ---
#
# ## Utility Functions

# %%
def clean(text):
  text = str(text)
  text = re.sub('\n',' ',text)
  text = re.sub(' +',' ',text)
  return text

# %%
def remove_outliers(data):
    """
    Removes outliers from a list of numbers using the Interquartile Range (IQR) method.

    Parameters:
    - data: list of numbers (integers or floats)

    Returns:
    - list of numbers with outliers removed
    """
    # Calculate Q1, Q3, and IQR
    Q1 = np.percentile(data, 25)
    Q3 = np.percentile(data, 75)
    IQR = Q3 - Q1

    # Define bounds for non-outliers
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR

    # Filter out outliers
    filtered_data = [x for x in data if lower_bound <= x <= upper_bound]

    return filtered_data

# %%
def remove_prompt_format(prompt, filename):

  prompt = clean(prompt)

  if "llama" in filename:
    if "[/INST]" in prompt:
      splitted_prompt = prompt.split("[/INST]")
      prompt = splitted_prompt[-1]

  elif "longform" in filename:
    if "Output the generated story directly." in prompt:
      splitted_prompt = prompt.split("Output the generated story directly.")
      prompt = splitted_prompt[-1]

  elif "openchat" in filename:
    if "Output the generated story directly." in prompt:
      splitted_prompt = prompt.split("Output the generated story directly.")
      prompt = splitted_prompt[-1]

  return prompt

# %%
def mean_pooling(model_output, attention_mask):
    token_embeddings = model_output[0] #First element of model_output contains all token embeddings
    input_mask_expanded = attention_mask.unsqueeze(-1).expand(token_embeddings.size()).float()
    sum_embeddings = torch.sum(token_embeddings * input_mask_expanded, 1)
    sum_mask = torch.clamp(input_mask_expanded.sum(1), min=1e-9)
    return sum_embeddings / sum_mask

# %%
def get_text_features(text):
  nlp = spacy.load("en_core_web_sm")
  doc = nlp(text)
  LFTK = lftk.Extractor(docs = doc)
  LFTK.customize(stop_words=False, punctuations=False, round_decimal=5)

  surface = lftk.search_features(domain = 'surface', language ='en', return_format = 'list_key')
  syntax = lftk.search_features(domain = 'syntax', language ='en',return_format = 'list_key')
  lexico_semantics = lftk.search_features(domain = 'lexico-semantics', language ='en', return_format = 'list_key')
  discourse = lftk.search_features(domain = 'discourse', language ='en',return_format = 'list_key')

  feature_list = surface + syntax + lexico_semantics + discourse
  extracted_features = LFTK.extract(features = feature_list)

  extracted_feature_list = list(extracted_features.values())

  # returns a list containing the extracted features
  return extracted_feature_list

# %%
def get_sbert_embeddings(text):
  encoded_input = bert_tokenizer(text, padding=True, truncation=True, max_length=512, return_tensors='pt')

  #Compute token embeddings
  with torch.no_grad():
      model_output = bert_model(**encoded_input)

  #Perform pooling. In this case, mean pooling
  sentence_embeddings = mean_pooling(model_output, encoded_input['attention_mask'])
  sentence_embeddings_np = sentence_embeddings.numpy()
  return sentence_embeddings_np[0].tolist()

# %%
def get_text_features_xgb(text):
  nlp = spacy.load("en_core_web_sm")
  doc = nlp(text)
  LFTK = lftk.Extractor(docs = doc)
  LFTK.customize(stop_words=False, punctuations=False, round_decimal=5)

  feature_list = ['t_word', 't_stopword', 't_syll', 't_syll2', 't_syll3', 't_sent','t_char', 'a_word_ps', 'fkre', 'fkgl', 'fogi', 'smog', 'cole', 'auto','a_adj_ps', 'a_adp_ps', 'a_adv_ps', 't_kup', 't_bry','t_subtlex_us_zipf', 'a_kup_ps', 'a_bry_ps', 'a_subtlex_us_zipf_pw','a_subtlex_us_zipf_ps', 'corr_noun_var']
  extracted_features = LFTK.extract(features = feature_list)

  extracted_feature_list = list(extracted_features.values())

  sbert_embeds = get_sbert_embeddings(text)

  # returns a list containing the extracted features
  #print(extracted_feature_list)
  combined_features = sbert_embeds + extracted_feature_list
  return combined_features

# %%
def get_level(text, model):
  text_features = get_text_features(text)
  text_features_np = np.array([text_features])  # Convert to 2D array
  predictions = model.predict(text_features_np)
  return predictions[0]

# %%
def get_level_xgb(text, model, column_names):
  text_features = get_text_features_xgb(text)
  text_features_df = pd.DataFrame([text_features], columns=column_names)
  text_data_dmatrix = xgb.DMatrix(text_features_df)
  model_prob = model.predict(text_data_dmatrix)

  #gives a string which is the label directly
  return int(model_prob[0])

# %%
def get_distinct_n(text, n):

  words = word_tokenize(text)
  ngram_lists = list(ngrams(words, n))
  ngrams_items = [item for sublist in ngram_lists for item in sublist]  # flatten

  # returns real number
  return len(set(ngrams_items)) / len(ngrams_items) if len(ngrams_items) > 0 else 0.

# %% [markdown]
# ---
#
# ## Main Script

# %%
# CEFR - cambridge_features.csv
# CCS - commoncore_10_features_bin.csv
features_df = pd.read_csv("commoncore_10_features_bin_with_sbert.csv")
features_df.head()
# Out:
#    sbert_1  sbert_2  sbert_3  sbert_4  sbert_5  sbert_6  sbert_7   sbert_8  \
# 0    0.300  -0.2550  -0.0445   0.2440    0.513   0.0350  -0.2200  0.032700
# 1    0.119   0.0903  -0.1300   0.2470    0.340   0.0817   0.0111  0.069300
# 2    0.327  -0.3680  -0.2450   0.0728    0.415  -0.1950  -0.0368 -0.051100
# 3    0.194  -0.1160  -0.1230   0.3520    0.177  -0.0724   0.1200  0.000226
# 4    0.200  -0.1570  -0.0504   0.3390    0.301  -0.1420  -0.1010  0.000105
#
#    sbert_9  sbert_10  ...  a_adv_ps    t_kup       t_bry  t_subtlex_us_zipf  \
# 0   0.0845   0.07380  ...   0.81553  5757.81  5197.94127         7259.26996
# 1   0.1160   0.00880  ...   0.37931  1001.62   909.90801         1217.22093
# 2  -0.1080  -0.00567  ...   1.04082  4752.32  4052.65006         5217.80707
# 3   0.1530  -0.11900  ...   0.42857  1034.07   870.80984         1102.57760
# 4   0.0728   0.05620  ...   0.61905   927.49   776.53675         1073.50981
#
#    a_kup_ps  a_bry_ps  a_subtlex_us_zipf_pw  a_subtlex_us_zipf_ps  \
# 0  55.90107  50.46545              13.36882              70.47835
# 1  34.53862  31.37614              12.54867              41.97314
# 2  96.98612  82.70714              14.86555             106.48586
# 3  73.86214  62.20070              14.89970              78.75554
# 4  44.16619  36.97794              11.54312              51.11951
#
#    corr_noun_var  level
# 0        5.99645      1
# 1        2.53898      1
# 2        5.98215      1
# 3        3.83761      1
# 4        3.05505      1
#
# [5 rows x 794 columns]

# %%
y = features_df['level']
X = features_df.drop('level', axis=1)

y = y - 1

# Split the dataset into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, random_state=42)

# %%
# Create and train the XGBoost model for CCS

dtrain = xgb.DMatrix(X_train, label=y_train)
dtest = xgb.DMatrix(X_test, label=y_test)
params = {
    'objective': 'multi:softmax',
    'num_class': 2,  # Number of unique classes
    'max_depth': 3,  # Depth of the trees
    'eta': 0.1,      # Learning rate
    'verbosity': 1   # Verbosity of printing messages
}
num_round = 100  # Number of boosting rounds

xgb_model = xgb.train(params, dtrain, num_round)
predictions = xgb_model.predict(dtest)
accuracy = accuracy_score(y_test, predictions)
print(f"XGBoost Accuracy: {accuracy}")
# Out:
# XGBoost Accuracy: 0.9166666666666666

# %%
# Create and train the Random Forest model
rf_model = RandomForestClassifier(n_estimators=100, random_state=42)
rf_model.fit(X_train.values, y_train.values)

# Make predictions
y_pred = rf_model.predict(X_test)

# Evaluate the model
accuracy = accuracy_score(y_test, y_pred)
print(f"Random Forest Accuracy: {accuracy}")
# Out:
# Random Forest Accuracy: 0.9117647058823529
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:432: UserWarning: X has feature names, but RandomForestClassifier was fitted without feature names
#   warnings.warn(

# %%
# Plus prompt and generation data here
# CEFR - elg_data.csv
# CCS - coca_data.csv
prompt_file_name = "coca_data.csv"
generation_file_name = "coca_longform_3b_aspect.csv"

prompt_df = pd.read_csv(prompt_file_name)
gen_df = pd.read_csv(generation_file_name)

prompt_list = prompt_df['prompt'].tolist()
level_list = gen_df['level'].tolist()
level_list = [x - 1 for x in level_list]
generation_list_raw = gen_df['generated_story'].tolist()

# %%
generation_list = []
counter = 1
for i in generation_list_raw:
  #print(counter)
  cleaned_generation = remove_prompt_format(i, generation_file_name)
  generation_list.append(cleaned_generation)
  counter += 1

# %%
prediction_labels = []
distinct_n_scores = []
for prompt, generation in zip(prompt_list, generation_list):

  # Calculate distinct_n
  distinct_n = (get_distinct_n(remove_prompt_format(generation,generation_file_name),3))
  distinct_n_scores.append(distinct_n)

  # Calculate accuracy
  print(generation)
  print(len(X_train.columns))
  prediction = get_level_xgb(generation, xgb_model, X_train.columns) # change to get_level_xgb and xgb_model for XGBoost and CCS
  #prediction = get_level(generation, rf_model)
  print(prediction)
  prediction_labels.append(prediction)
# Out:
#  A river of flames ran down the middle of the street, burning cars and people. It had been raining for a while, so the streets were covered with thick mud. All of a sudden, the rain stopped, and the sun came out. The fire moved from the middle of the street to the other side, and then the rain came back again. After that, the sun stayed out, so the mud disappeared again, and people woke up the next morning to a beautiful day. The story ends on this beautiful day.Mr. Anderson had been on holiday for the last few weeks, and on his return he noticed that his house had become rather messy. All of the furniture was turned upside down, the bed was pushed to the wall and Mr. Anderson had lost all of his valuable books. The police were informed, and it seemed that it was a case of robbery, as all of the valuable stuff had been stolen. But no-one was found who had done it. The house was cleaned up and Mr. Anderson found that everything was in order again. He was grateful that no-one had broken into his house. And the next day, he saw that the river of fire was back again, even though he hadn't seen any fire earlier in the year. It was the same as it had been last year. But that was not the only thing that had been the same: the clothes were all different, and they had no names on them. Mr. Anderson
# 793
# /usr/local/lib/python3.10/dist-packages/spacy/util.py:1740: UserWarning: [W111] Jupyter notebook detected: if using `prefer_gpu()` or `require_gpu()`, include it in the same cell right before `spacy.load()` to ensure that the model is loaded on the correct device. More information: http://spacy.io/usage/v3#jupyter-notebook-gpu
#   warnings.warn(Warnings.W111)
# 0
#  Two people are sitting at a café, drinking coffee and eating pancakes. The first guy orders a cappuccino, but the waitress mistakes it for a cappuccino and gives him a latte. To prove it to the waitress, he orders another cappuccino and asks the waitress for a latte as well. Then the waitress takes out the right cappuccino and gives him the wrong one. The second guy, watching this, laughs and says: "I can't believe that!" The first guy looks sad and says, "We're in trouble now!" To which the other guy replies: "No, no, no, I just made a mistake. Don't worry about it!" They both laugh and take the cappuccino/latte mix and put it back. Then, with a sip of their coffee, they take another bite of their pancakes and sip their coffee, and continue laughing together. Now, the first guy asks: "So what were you doing?" The other guy says: "I was eating pancakes." The first guy responds: "Pancakes have a mystery, too. They're hard to eat, because they're long and have lots of short words in them. But, they also have a short, easy to read sentence in the middle. Pancakes have a story you can figure out just by reading the word 'pancakes'. But, I'm sure there is another way
# 793
# 0
#  Sylvia and her boyfriend visited the forest near their house to look for a new tree house. Since they could not find one, Sylvia looked for an old one they used to visit as a child. One day she noticed that the tree that the tree house was built on was dying, and she was afraid that the tree would be cut down. As she was sitting in the tree house, she saw the big bird fly towards her. She was afraid it would destroy the tree and thus they would die. The bird landed in the tree, and a loud cry was heard. The bird asked Sylvia why she made it angry, and she admitted she was afraid it would harm the tree. The bird asked again why she was afraid, and she answered because she was wrong. The bird asked her again why she was wrong and told her that the tree was not alive. The bird asked her a third time if the tree was dead, to which she replied yes. The bird told her she was correct about the tree being dead, but she was wrong about who was responsible for it. The bird told her that she was wrong because she was afraid of the bird. The bird then left and asked for her forgiveness. She replied she had been wrong about all three things. She then asked if she could have a snack and told her she could eat one slice of fruit. The bird replied it was not allowed to leave the tree and told her she would be allowed to have a snack when she ate the
# 793
# 0
#  In a dream, I was a human. My body was not the human body but a very strong machine. My face was not human face but a machine made to look like human face. In my dream I woke up suddenly. My friend told me that his wife had been attacked by dogs in their dream. I was shocked to hear it. In my dream when I saw my friend with his wife, I went away from the dream and slept again.One night, a man had a dream. He was standing at the edge of a pond, gazing into the water. Looking over the water, he could see a large number of animals, all floating around in the water. He saw a dog come up to him, and the man petted it gently on the top of its head. He saw another dog, about the size of a human, trotting along beside the first dog. Another large dog was also there, with what looked like a human head on its back. Finally, a man could see a large black pig floating on the surface of the water. The man stroked the pig's back gently, smiling at the pig. Finally, he dreamed that he came to life again, and was able to walk around. When he looked around, he could see that there were no animals around. Then he woke up. The man was very disappointed to wake up
# 793
# 0
#  Secret 1. She didn't want to talk about it. She had no intention of talking about it. 2. There are all sorts of secrets. I know some people who know others who know more. 3. I'm going to get my secrets out now before something happens. I'll probably regret it. 4. There are many secrets. I know secrets, I've heard many secrets. 5. I don't know why she did this. I don't even know why she did that. She did it out of a secret. She didn't mean to do this. 6. He didn't say a word. He didn't say a word to the teacher. He didn't say a word to the principal. 7. She didn't want to talk about it. She had no intention of talking about it. 8. There are all sorts of secrets. I know some people who know others who know more. 9. I'm going to get my secrets out now before something happens. I'll probably regret it. 10. There are many secrets. I know secrets, I've heard many secrets. 11. He didn't say a word. He didn't say a word to the teacher. He didn't say a word to the principal. 12. She didn't want to talk about it. She had no intention of talking about it. 13. There are all sorts of secrets
# 793
# 0
#  It was a grand adventure. Every journey was a different one and each one of the journeys was a great adventure. It was the most beautiful sight and it was like seeing it for the first time. They had a lot of fun. They had seen lots of different animals. They had run with elephants and felt their strength. They had seen crocodiles and watched them eating fish. They had walked for days over the desert. They had lived in the ocean and walked across the sand with sharks in the sea. They had slept under the stars and listened to the sea birds singing. Then it was time to see the wonder of the world, the Taj Mahal. They were amazed that the building has stood for so long. They wanted to see the white tiger and had heard that it was a very special animal. They left to go see the tiger in the forest and it was amazing to watch the tiger come out of the den. The tiger saw the children and had fun and play with them. He was quite beautiful and it was a moment they will never forget. But then came the time to leave and go home. They were sad to leave the beautiful place but they were happy to go back home. They all had a great time. They felt that they had experienced the journey of a lifetime. Journeys are grand adventures and the children from the zoo went on many of them
# 793
# 0
#  I think there is a treasure that was lost or hidden somewhere in the forest, the clues about it were written on the door and somebody was murdered on the same day. When a cop went to find the killer he met the killer's sister and the brother who was there too. They said they never knew any of that. Who is the murderer?A young couple was having a picnic on a secluded beach when they started to discuss their future and the children. The man said he wanted to have a child and the woman did not. However, she said she would marry him anyway and agreed to adopt a child. When the couple was on the return trip, the woman suddenly felt severe pains in her abdomen. She started to complain of pains but her husband said she was not in pain at all. Suddenly she got out of the car and fell to the ground, crying in pain. The man told her to lie down so she could get a better view of the pain she was feeling. She laid down on the ground and her husband ran back to the car. When they reached the nearest hospital, the woman became even more ill. They took her to surgery and her surgery went well, except her surgeon died in the same surgery. During the surgery, it seemed that the husband was doing CPR but they found out after they took her out that he wasn't doing anything and was just standing at the door, saying nothing. The man was then arrested and the woman didn't seem to be
# 793
# 0
#  Aquatic Life I have been on the river ever since. In fact, you could say I was born there. Because, to be honest, there is nothing more enchanting than a flowing river. You can go swimming, canoeing, rafting, and just sit and be at one with the nature and all of the little creatures that populate it. So, what can you do when you are there? I am not sure, but I do know that one of the best ways to have a good time is to swim! You should never swim in the ocean, of course, because that is crazy, but there is a river that is perfect for swimming in. The river has just enough current that it is not too dangerous, but enough that it will keep you out of trouble. For me, there is only one thing better than swimming in that river and that is fishing! I never get tired of fishing. I can be in the midst of the most amazing lake and be fishing before I realize it. But, it is different when you are out on a river that is flowing. There is something more wonderful about a river than a lake or a bay. The thing about a river is that it is always flowing and it never ever stops. That is a wonderful thing about the river. The other thing I love about it is that there is always a million fish waiting to bite. It is a pretty exciting thing to have that many fish around to chase. This is
# 793
# 0
#  In the beginning there was a battle. In the beginning there was no battle, but one small thing happened. The small thing was that a single leaf fell. The narrator and the leaf have been friends for ages. The leaf likes this book and the narrator enjoys the leaf. The leaf is always around the narrator's side. The leaf is always watching for the narrator's movements. The leaf watches the narrator carefully. The leaf looks for the smallest change in the narrator's movement. If that change happens, the leaf knows. One day the narrator decided to put on his armour and go to battle. The narrator put on his armour and went to battle. The narrator thought he was prepared for battle. It was his first time in the armour, but the armour seemed comfortable. The narrator put his head into the helmet and he couldn't breathe anymore. When the battle was over, he was back at his friends house, but there was no leaf. This is a simple story. The narrator decides to go to battle, putting on his armour and everything is fine. Then he realizes he can't breathe when he puts on the armour. This is a sign he is ready for battle. This is a story about the
# 793
# 0
#  This myth is a myth. No good myths come from mythology. There is too much to know about myths to tell them, and most of what is known is wrong. Myth is only a word for an invented story, not for an unmade one. Mythology is a real science, based on observation. It is based on a theory of how people learn, based on what they actually know. This theory was based on observations about what they know, and it is still true today. There is a lot we don’t know about mythology. We don’t know what makes it effective, or why people believe it. We don’t know why people like to read about it. We don’t know what makes myths effective. What we do know is that myths will not work for you, and that if you do have a myth, then it is not a myth. If you follow the myth you will find that it doesn’t work. This means you can create a myth of your own. You can create a story that is based on something real, even if the something is made up. You can use something real that people have believed in. You can make up something real that people believe in. But you can’t use the myth of something real that people have not. The thing that people didn’t believe in would never be able to be a myth, even if you are able to make it so real
# 793
# 0
#  The monster lives in the deep dark wood. He eats the small animals. He is not friendly. He doesn’t like the people. The small animal called a frog lives in the stream. One day, he ate the frog. The big animals who eat the small animals are not friendly. They don’t like the people. The big animal called a elephant lives on top of the big rock. He eats the small animals. He is not friendly. He doesn’t like the people. The big tree which grows in the forest is not friendly. It’s very big. It has many small branches on it. It’s very strong. It’s not friendly to the monster and the people. The bird lives on the tree and the sky. He eats the small birds. He is not friendly. He doesn’t like the people. The lion is very strong and very tall. He has large eyes and a great nose. He eats the small animals. He is not friendly. He doesn’t like the people. The turtle lives in the pond. He eats the fish. He is not friendly. He doesn’t like the people. The lion is friendly to the people. He likes to play with them. He lives on the mountain. He likes to eat fruit from the trees. He is not friendly. He doesn’t like the people. The deer lives
# 793
# 0
#  Today’s story is about heroes. It will start with my father. He went to the doctor for a routine check up in which his weight and height were checked. After examining him, the doctor told my father to stop smoking. But my father’s stubbornness didn’t allow him to stop smoking. My father refused to go to gym either. He just sat at home in bed watching his TV all day. One day my grandfather brought a new television set. The next day he received another gift. This time it was a new pair of shoes. Finally, on the following week, he received another gift. After a little while, my father went to the doctor again. The doctor told him that he was too fat. He should lose more weight and exercise for three months. In the same way my mother didn’t go to gym. Neither did my grandfather. They watched TV all day too. One day my parents got a new car. The next day, my father received yet another gift. This time he got a new watch. However, a few days later, my father went to the doctor for a routine check up. The doctor told him to lose another five pounds and exercise. My grandfather went to the doctor too. The doctor said that he was too old and overweight to lose weight. My mother went to gym but my father went to the doctor every month. My grandfather always had the same problem: his weight, but my
# 793
# 0
#  The Secret of the Spell Spell 1 All the spells were written by children. It seems the witch was the only one who knew their secret. She took the spells for herself. The witch gave each spell to a different monster or animal. Rabid rats, greedy foxes, mean mice and ugly frogs all had a spell that was theirs. After that, the witch took all the spells for herself. The children lived in fear of the witch's cruelty. The children knew that the spells were dangerous. They didn't have a clue. Who would be next in her list? All the children did was cry. They couldn't go to the school because of the witch's spells. They couldn't go to their houses because she had their spells. The witch's power made them angry. There was no hope. There was no escape. What can they do? They couldn't give up and wait for death. That would be the end of them all. They had to die, but not die. They had to be reincarnated. They had to be reborn. The children would have to learn to cope with her cruelty. They had to face the truth. The truth was that the witch had the power. In the darkness the children would sleep. At night, the witch would take the spells. All the children would wake up. There was
# 793
# 0
#  Kingdoms" The first kingdom had a lot of trees. There were three princesses living in this kingdom. They were Sis, Katerina, and Kaira. The third kingdom had a lot of lakes and a mountain with a waterfall in it. There were three princesses living there. They were Princess Inger, Princess Julia, and Princess Alysia. Their land was next to the lake that had the waterfall in it. The fourth kingdom had a lot of mountains and plains. Their princess was named Elisabeth and their king was named King Louis. Their land was next to the lake that had the waterfall in it. The fifth kingdom had a lot of forests. Their princess was named Amalia and their king was named King Philip. Their land was next to the lake that had the waterfall in it. The sixth kingdom was next to a lot of sand dunes. Their princess was named Zara and their king was named King Roger. Their land was next to the sand dune that had the waterfall in it. The seventh kingdom had a lot of islands. There were three princesses living there. They were Princess Maria, Princess Isabella, and Princess Isabel. Their land was next to a lot of seas. Their princess was named Rosalie and their king was named King Louis. Their land was next to the seas. The eighth kingdom had a lot of hills. Their princess was named Agnes and their king was named King Robert. Their land
# 793
# 0
#  Two fishermen were on a boat when an animal jumped out of the water towards the boat. The first one shouted "That's one mean fish." The other one shouted "That's a mean fish". The first one was left alone. The second one died. Title:"Mean Fish"Two fishermen were on a boat when an animal jumped out of the water towards the boat. The first one shouted "That's one mean fish." The other one shouted "That's a mean fish." The first one was left alone. The second one died. Title:"Mean Fish" Generate a short story based on the theme of the topic word and make sure it is readable for grades 6 to 8 learners in the Common Core Standards scale and observes the following specifications: 1. Meaning or purpose: The text can range from containing a single level of meaning to multiple levels of meaning based on complexity. 2. Structure: A text with low complexity tends to have simple, well-marked, and conventional structures, whereas a text of high complexity tends to have complex, implicit, and unconventional structures. Simple texts tend to relate events in chronological order, while complex texts make more frequent use of flashbacks, flash-forwards, and other manipulations of time and sequence. 3. Lengths: That text that has longer words and longer sentences are more difficult to read than shorter ones. A text with many long words and
# 793
# 0
#  "Voyage" is a very complex word for a young person to understand and pronounce. Our project is based on reading a story that has very complex meanings. We found that the story was very interesting and we liked its story. We would love to publish the story on our blog. Since we like the story so much, we want to include this story to our English homework tomorrow. We hope you understand how excited we are to have this story to read to our teachers tomorrow. We wish our English homework would be as exciting as the story we are going to write tomorrow. We hope you understand our excitement as we are writing our assignment for tomorrow. If you have time, please take a look at our blog. We have a lot of interesting articles and we hope you like it. We hope you can look at our blog and see that we like it. We do our English homework in the morning, so we always have time to look at it. We hope you will look at our blog. We will put the link at the bottom of our blog and on the side bar. We want to put a link in the middle of our blog. Please write back to us if you have any question about our blog. We are very excited to have our English homework, tomorrow. We can't wait until tomorrow. This is going to be very interesting. We hope you understand how excited we are. See you tomorrow. You know you like our blog when you look at it every morning,
# 793
# 0
#  A family walks on a park to enjoy the beautiful sunny day. They pass by a shop and it smells strongly. The family smells the smell from the shop. That smell makes them all a little angry. They are all annoyed. The mother is annoyed, the father is annoyed, the older daughter is annoyed, the younger daughter is annoyed and the baby is quite happy. The mother and father think it's a very annoying smell, even though the baby doesn't care. After passing by that shop and the baby being a little happy, they are a bit better and have not been as angry and annoyed by that smell. The next time they pass by that shop they are annoyed. The smell of the shop is strong and they smell it again. This time they are annoyed by the smell of the shop and they are mad with their family. They go out of the park and into the park, to get away from the smell of the shop. The baby has also forgotten about the smell of the shop. The family is now happy again. The baby doesn't smell the smell of the shop. The baby doesn't care anymore. They are all a bit happier. The baby doesn't smell the smell of the shop. The baby doesn't care anymore. The family is very happy now. The baby doesn't smell the smell of the shop. The baby doesn't care anymore. They are all a bit happier. The baby doesn't smell the smell of the shop. The baby doesn't care anymore
# 793
# 0
#  The museum is currently displaying the remains of the Titanic, one of the most famous vessels in the world. The boat had two decks: the upper deck and the lower deck. The upper deck was occupied by the passengers, while the lower deck was used only for cargo. The Titanic was the first and largest passenger liner. She was traveling between Liverpool and New York City when she caught fire and hit an iceberg on April 15, 1912. After hitting the iceberg, the Titanic lost her stability and started to sink to the ocean. Her passengers and crew died one by one. Some people managed to escape and survived by swimming in the lifeboats. As the passengers died one by one, the upper deck became full. People were forced to move to the lower deck, in which cargo was stored. The lower deck became overcrowded as well. The passengers became desperate and decided to abandon the ship by swimming into the open water. But because of the freezing water and strong currents, most of them died. This was the worst tragedy that the world had ever experienced. The survivors then continued their journey to America. They had to travel for another 100 days before they reached New York. The whole thing took about a year to complete. On the way, some of them survived by eating the raw fish that floated on the surface. In the museum, you can read about this tragic event.
# 793
# 0
#  "Beast" The beast lived in the forest, a creature of great power. He lived in a time before humans, long ago. He lived and walked in the ancient time, for he is one with the tree, the tree is one with the beast. The beast lived in a land where he could roam, away from his mate, but he would see her, even if she went to another tree, a sign that their bond was stronger than the forest they call home. The beast knew his time was running out. For he had become the prey of the hunters, for he was but one of many beasts caught in the hunt. The hunters would return, every year, to the place where the beast lay. All the beasts would try to escape the hunters. But every year one beast would be the last, for the hunters would come. But that beast would be lucky for they would hunt just for the beast, and leave the others alone.
# 793
# 0
#  The islands are not large. There are only three, and all are in a row, with the middle one in the center and the other two on either side. They are in a very wide spot with the ocean in both sides. They are very white with gray rocks, as if there were no water on them. They have small trees with blue flowers that hang from the branches that hang out the top. There are also two trees where the flowers are, and they are white with red centers. There are small people who live there. They are a big red that looks like a big potato, and they go out to collect sea shells to make red potatoe. The people wear clothes and they are not yellow. They have yellow heads and hands, and their clothes are pink with purple flowers. There are a lot of orange flowers on the bushes in front of the island. The island has a lot of birds, but none of them look like a duck. They all look like big butterflies or something. There is a lot of rocks to climb on, but they have very tall cliffs. The rocks are all big and have lots of holes on them. There are big fish that live in the water, but the islands have no water in them. It's very dark at night, but the light is a orange light. The island that is in the center is the smallest. The people there are big. They have yellow legs and green
# 793
# 0
#  The adventures of Sooty the Squirrel and Snuffy the Bunny are being presented to all the residents of Bumperville. The task is for you to rewrite them into a poem that involves the use of a word that is associated with the subject of the story.The adventures of Sooty the Squirrel and Snuffy the Bunny are being presented to all the residents of Bumperville. The task is for you to rewrite them into a poem that involves the use of the word that is associated with the subject of the story.The adventures of Sooty the Squirrel and Snuffy the Bunny are being presented to all the residents of Bumperville. The task is for you to rewrite them into a poem that involves the use of the word that is associated with the subject of the story.The adventures of Sooty the Squirrel and Snuffy the Bunny are being presented to all the residents of Bumperville. The task is for you to rewrite them into a poem that involves the use of the word that is associated with the subject of the story.The adventures of Sooty the Squirrel and Snuffy the Bunny are being presented to all the residents of Bumperville. The task is for you to rewrite them into a poem that involves the use of the word that is associated with the subject of the story. Provide a brief overview of the concept of science.Science is based on understanding of the natural world and is often a combination of practical knowledge and
# 793
# 0
#  Fantasy Realms
# 793
# 1
# A Challenge Today I learned a challenge.
# 793
# 1
#  Fables (Fāblēs) [ˈfæblēs] is a literary type in which animals or humans, or parts of these, are presented as tales intended to teach moral lessons, usually for adult audiences.  *  *  *  *  *  *  *  *  *  *  *  *  *  *  *  *  *  *  *  * It was a long, hot summer in the North Woods. It was the most beautiful summer. The wolves lay around the campfire talking about the coming winter. "When do you think the first snow will fall?" asked the gray wolf. "I bet it will be early next month," replied the brown wolf. "If we have one more warm, sunny week, I bet it will snow by Christmas," said the grey wolf. But the next winter they had a very different winter. "This will be one of the warmest winters in a long time," said the grey wolf, "and if we have another warm, sunny summer - that will be even warmer." But then, the winter after that, the winter after that - they all had
# 793
# 1
#  Three young teenagers were sitting on a bench, waiting for the train to take them to their destination. One of them decided to read some famous book written by Albert Einstein. The other two asked him about the book, and what it was about. He told them that the book was about something like, the power of thinking. The third one asked him to tell him some of the important points and words from the book. He told him that it was about something like, The power of believing. The first one understood the book by that and read it whole night. The second one learned the book for two days and started to read it also, but she did not get the idea how it is about something like, the power of believing. After the third day, she thought that this is a really interesting book and asked her friend to help her to read it. He told her that it is about something like, the power of believing, for example, believing in something. She did not understand the book by that and did not read it too. The next morning they were all together again, and the book was still not understood by any of them. The fourth day passed and they did not understand the book any more. They went to school and the teacher told them that their book was about something like, the power of thinking. She read it for two days, and she understood it. The book is finished.The three teenagers were reading a book written by Albert Einstein. The girl
# 793
# 0
#  She loved the magic of the dark and mysterious forest. She loved the magic of sorcery. She loved to summon forth spirits. She loved to speak of spells. She loved the dark. She loved magic. The following is a translation from the original text: Hi there! I'm going to show you some magic. I'm going to teach you how to cast spells. I'm going to talk about all the dark things in the forest. But before we start this lesson, let's have a rest. Let's have a cup of tea. Let's talk a bit about how to stay healthy. Well, to sum up everything you know, I'd like to leave you with these words: A word of advice about the dark and mysterious forest. Be very careful because there are lots of bad people there. They can kill you without any hesitation. They can take away your happiness without you even knowing it. They can harm your family without even knowing it. They can do terrible things to animals. You should be very careful in the dark and mysterious forest. It's dangerous. Stay away from people who are evil. They will do bad things to you. You should never trust people like this. They are bad people. They are horrible.
# 793
# 0
#  It was a rainy day on a pirate ship. Jack Sparrow was the ship's skipper. There were four pirates: Johnny Depp, Kate Moss, Johnny Galecki, and Seth Rogen. They were all trying to steal a giant gold heart from another ship. Their plan was to hide it in a tree and then use it as a ship's compass. Their search was tough because pirates are not as fast as they should be. The rain was making it harder to see anything and pirates could easily get lost. Suddenly, Johnny Galecki heard a rumble in the sky. Everyone hid under a rock and watched in horror as a giant cannon shot through the sky. It blew up part of the ship and turned it into a giant heart. The cannonball's path went straight to Johnny Depp and Kate Moss' ship. It was so big that it nearly hit Johnny Depp's eye. It was so powerful that it turned the ship into a giant heart. The rain slowed down and suddenly Johnny Depp was in a pirate outfit. He opened the giant heart and discovered a giant map with a red dot on it. It pointed to a pirate ship with gold horns. They sailed to the pirate ship and discovered that it was on fire. The fire burned even faster when the golden horns
# 793
# 0
#  "The Shadow of the Dragon" I looked at the window. It was sunny, and spring was in the air. There was something in the window. It was so bright that I couldn't take my eyes off it. I wanted to look, to see if it was a dragon. I waited for a while but the thing didn't move. There was nothing on top of the house, but what I saw looked like a shadow. It was in the window for a very long time. I couldn't wait any longer. I started to cry. "Let's go to the museum!" I thought. "I want to see if it is a real dragon." I opened the door and came out into the street. There was a man sitting in a chair. He looked so sad, like he wanted to be somewhere else. I went up to him and asked, "Are you looking for a dragon?" "No," he said sadly. "The museum will be open soon. But that's where the dragon is. And I'm never going there again." I gave him a hug and he disappeared in the crowd. I left the man, went into the museum, and looked around. It was a beautiful place. It was big and tall and round. There was a wall with some paintings on it. One of them was very old, it was black and green and brown and yellow. I looked closely at
# 793
# 0
#  The Sorcerer's Apprentice The Sorcerer's Apprentice is a fun adventure story that involves a young boy named David. He is a small child and a very talented child magician. His parents always try to stop him from doing magic, and he has a habit of trying it on his friends. When his grandmother comes to stay, things get more and more complicated. Grandmother is very kind and patient and does not wish to interfere with David's magic tricks. But unfortunately, he manages to trick an old woman named Mrs. Puddifoot. Mrs. Puddifoot accidentally falls asleep in the shop. David goes and tries to wake her up. However, she had fallen into a deep sleep and when she finally wakes up, she starts speaking nonsense. David is happy that she is awake. She seems to be fine now. Mrs. Puddifoot starts telling David the story of her adventures during the day. She is still trying to remember what happened to her when she was sleeping. David takes her to the castle, where the sorcerer and his daughter are sleeping. He tries to steal a magic book, but it is guarded by the dragon, that does not want him to get it. David tries to trick it, but it catches him and he is injured. While David was unconscious, the dragon attacked the sorcerer, who had fallen asleep with a very large stomach pain. The sorcerer and his daughter had to hide at the bottom of the staircase, where the dragon tried to bite them.
# 793
# 0
#  Fortresses The village was peaceful but for the fortress. It was tall and strong as a lion, and was made entirely of wood. The castle could stand against a hundred attackers and was only captured by the enemy after a week of fighting. It was a beautiful piece of architecture. ‘But if we had it,’ thought the king, ‘there wouldn’t be anyone to invade us.’ The fortress had a castle, a dungeon and a moat. The dungeon was an enormous room that could hold a hundred prisoners without ever getting full. The castle was made of wood, so it could protect the fortress from the outside while the wood-cutters worked inside. And the moat was wide enough to swim in. It was a terrible place for people to live, but it was a great place to hide from the attackers. They could hide inside and fight from there. And there was always the risk that they might escape and fight even more defenders. The king and all his men wanted a fortress. But a fortress was not easy to build. It had to be strong enough to defend against an attack, but also large enough that it would protect other villages and towns. It had to be safe. And of course, it had to be beautiful. It was a hard task, for it is much more difficult to build a fortress than it is to build a
# 793
# 0
#  One time, there was an alien named Larry, who came from far away planet. He looked really smart and he wanted to be friends with Larry, the human. However, Larry, the human, was lazy so he never wanted to go outside. His parents said Larry, the alien, would stay outside and watch him, so Larry, the alien, started to come inside more. It was pretty fun, the alien watched Larry, the human. Then Larry's mom, the alien, asked her son to come outside. Larry, the human, agreed because he wanted to see Larry, the alien. The alien, Larry, said, "Thanks mom!" and flew away. That night, Larry, the human, went to sleep. The next morning, Larry's mom called him again. Larry, the human, agreed to come outside again. "Ok," he said. "Let's go outside!" He quickly picked up Larry, the alien, and he flew away. They lived happily ever after. Proofread this document and fix any errors that make it sound weird or confusing.One day, there was an alien named Larry. He came from far away planet. He looked really smart and he wanted to be friends with Larry, the human. However, Larry, the human, was lazy. His parents said Larry, the alien, would stay outside and watch him, so Larry, the alien, started to come inside more. It was pretty
# 793
# 0
#  A city of dimensions and colors was built. Dimensions in this case refers to the people that live in this city, and colors refer to the various ethnicities. The architecture of the city is simple and uniform in most parts, but in other areas there are very different looking buildings. The people themselves are divided into 5 main groups,
# 793
# 1
#  Galaxies We will go to the outer space and find out about the galaxies in the night sky. I saw a galaxy in space the shape is almost like a tree looks like a blue and green fruit. It was bigger than a house It was bigger than a horse It was bigger than the moon. When i was a kid my brother told me this is a galaxy it looks like the apple. I think this is how it should look. And the story will go like this. The sky will be blue and there will be green. And there will be an apple there and people will eat it. And after that they will go to the moon. So it was good to know that there are galaxies out there. You can put that in your resume. Thanks, I will give it to the boss. That was very interesting story. I liked the last line. The Galaxy There’s a Galaxy in the sky with beautiful light that shines. It’s a little red, a little blue, and a little white. It’s a galaxy with a star inside. It looks just like a tree and looks just like a shoe. I see it in the moon at night, I see it when I’m
# 793
# 0
#  The World of Robots You must give this task more than just a title. Make a short story, 3,500 to 5,000 words long, that covers the following topic words: robots.The World of Robots Robots came first as a very small and fast creature on this planet. This creature's name is a bit strange and they don't say its real name, the only person to ever meet it was the man and his robot name was "Sarge" and the robot was yellow with little wheels attached to the bottom and the man named "Dave" and he and sarge were really good friends and they went on a mission together and they were able to get a good enough picture of the robot before it disappeared it was very smart. Then there was an accident and this made the people from this planet to make a race of robots to take over the rest of the planet and they did very quickly and now they rule the planet. The most famous robot on this planet is the T1000 and he has a metal skeleton inside of him he has four laser like weapons on his head and he has this thing that makes him look like an eye and it even shoots the people on the other side of this door. Then there was this man named John Connor and he was the only one who could stop them and that is what he did and he beat the robots to death and then the robots turned into people and they were called Terminators the bad part is
# 793
# 1
#  I am a survivor of a violent school shooting at Sandy Hook Elementary School. I was there at the time when the shooting happened. The school was well lit and there were many adults with firearms, which enabled a good response. The shooter, Adam Lanza, was a quiet and very intelligent young man who seemed to have no reason for his actions. He entered the school and began killing children and adults with an AR15-type rifle, all of which were legally owned by his mother. She had not notified the police or done anything to alert them to her intention. He killed twenty five children and six adults, plus he killed himself after firing the rifle into the school and injuring himself in the process. For the survivors, the experience was traumatic and we felt pain and shock for a long time. This event affected our families, our friends, and myself. We have been receiving help from therapists and counselors at a local hospital in Newtown. The most important thing we have learned is that we need
# 793
# 0
#  The warrior-maiden had a great battle. They defeated two other warriors, which made them the most famous warriors. She did not sleep much in the night. But the warrior-maiden decided to go away with her beloved warrior to an island. They did not have any car. She decided to walk over the path. The grass was wet due to the rain. She walked for a long time until she arrived at the island. The island was beautiful. There was a lake, a forest, and a small temple. They rested there, and made a campfire. They ate well. The warrior-maiden had a long time to think about the battle, the victory, and the great love she had. She did not sleep well, but she was happy. The warrior-maiden decided to leave the island. She looked at the sunset on the lake. The island was covered with a cloud, and she saw a dragon. The dragon looked also at the island, and the warrior-maiden. The dragon would attack both of them, if the dragon ate them. The warrior-maiden wanted to hide with her beloved warrior, but the dragon was angry. The dragon did not want to leave them because they could eat them. The warrior-maiden did not want to die. She wanted to be alive so that she could fight the dragon. The dragon looked at them both, and decided to let them go. The dragon flew back to the ocean. The warrior
# 793
# 0
#  On the island of Santarosa, there is an adventure club called the Explorers Club. They are made up of nine brave explorers, who have mastered all sorts of incredible skills such as flying and climbing, and they have come from all over the world. The adventures the Explorers Club has been involved in are incredible and they would like to share this magic with as many children as possible. There is an exciting book about the Explorers Club, called The Adventures of the Explorers Club. It was written by the club's secretary, Alice. Although it is an interesting book to read, it is written in such a way that it is hard to read. The story is told in the third person, which makes it very hard to understand because the reader can't make out the author's feelings. It also doesn't help that the sentences in the book are long and complex, which is difficult for a reader to understand. For instance, one of the sentences in the book is "I was very worried about the future of the club. This was because if people didn't get involved, the club wouldn't exist." This sentence is hard to figure out because the reader has to figure out what the author's feelings are about the club. The author doesn't use any simple sentences or short sentences to make the story easier to read. Instead, it
# 793
# 0
#  On this day, in 1033 A.D., Rome was founded by a man named Romulus. Rome, the city of ancient Rome, flourished until the fourth century, when the city was sacked and destroyed by the Vandals. After that, it wasn't until 1476, that the city again enjoyed peace and prosperity, only to be destroyed for the fourth time in the twentieth century, by Mussolini's fascist regime. Today, the ruins of ancient Rome still stand on the shores of the Tiber River, as a symbol of the ruins of human freedom in Italy. Rome has always been a symbol of freedom for the rest of the world as well, a symbol of hope. Rome was a city, founded by a group of brave young boys who had a dream, a dream for the world. They had to fight for that dream until they finally achieved it. It's now their legacy to the world. If you would like to travel to Rome to see the ruins, you can get there easily by using an airline from somewhere like Seattle, or Atlanta. If you would like to travel by train to Rome, you can go from the city of Venice to Milan. You can also go from Venice, to Rome by bus, which is a more efficient way to travel than by train. This trip takes you a little over five days, which is a very long time, but it is still a very interesting trip. Given this topic word
# 793
# 1
#  "Empire State" refers to a vast network of power, influence, commerce, and commerce. The word empire comes from the Greek word, ("stater"). Empire is a system of government whereby a country or a ruler controls a great majority of the territory and all its inhabitants, such that its power and its influence extend over all other states and their leaders. This term is used in the context of a national economy, and means a power or control over a particular national economy. In the context of world geography, it means the control over a large geographic area, such as the control over the world's oceans. For example, New York city has an empire over the United States, the United States have an empire over the world, and the world has an empire over New York City. "Empire State" is also a noun, which refers to all the countries of the United States. This term is used in the context of the national government and refers to the power and influence that it has over all the states in the country. For example, the United States have an empire over the world, and the world has an empire over New York City. The United States are known by a certain name, which is an empire. They have an empire over all the states in the country, and the world has an empire over New York City. "Empire State" is also a verb, which refers to exercising authority
# 793
# 0
#  The Wizards of Oz The Wizard of Oz is the best known of all the many works by L. Frank Baum. He is best remembered for a little girl with blue hair named Dorothy and her dog, Toto. As they travel through the Wizard of Oz they encounter all sorts of characters along the way. It is a fantastical story that is set in the Land of Oz, where the Scarecrow, the Tin Woodman, the Cowardly Lion, the Wicked Witch of the West, the Flying Dutchman and his elephant Glinda are all enemies to Dorothy. At the center of the story however is the relationship between Toto and Dorothy. She adores him, and Toto does the same to her. Eventually they meet up with the Scarecrow, the Tin Man, the Cowardly Lion, the Wicked Witch of the West, and the Flying Dutchman and their battle begins. But who will be victorious? We will never know the end of this story as Baum is no longer alive. The Wonderful Wizard of Oz is a work of historical fiction because the story takes place in the past, but we can’t tell who is right and who is wrong. It is a classic because its story line is timeless. It has been made into many different adaptations over the years, including the animated television series The Wonderful Wizard of Oz, which came out in 1939, and the Oscar winning Oz films directed by L. Frank Baum.
# 793
# 0
# ...
# 793
# 0
#  A civilization grew and spread throughout the world, leaving their mark on many nations. The people of this empire were proud, strong, and feared by their enemies. However, the emperor of this empire grew tired of ruling and one night, he was abducted and transported to another realm. In this realm, the emperor was no longer surrounded by a powerful army of loyal soldiers and followers. In fact, this other realm had no people and the emperor and his followers were the only living beings. The king of this realm was unsure whether to let the emperor live or kill him. The king and the emperor agreed on a deal in which the emperor would be free to die after making a wish, but if the emperor's wish was to not be followed, then he would be killed instead. The king agreed to the terms and gave the emporer one last night to sleep before his death. The emporer wished for his soldiers to guard his empire at all costs. He wished for his people to be happy. While this wish was not the most difficult to accomplish, it was a bit risky. So, the emporer and his soldiers were happy and they protected their empire, but in return, the emperor and his followers could not be happy either. The king could not decide which way to go. One day, the king became tired of his position and made the difficult decision to kill the emperor, not because he was tired of his job, but because he was tired of being king. The
# 793
# 0
#  Ralph is a young wizard, his favorite pastime is playing chess, however, there are a few rules that he likes to follow. 1. He loves to play chess against others, but never against himself. This is because he knows that he could win his game if he wins the first move, yet he knows that if he makes his first move on his own, there is no way he can win the game. 2. He always has the most advanced chess pieces. For this reason, he always wins. 3. He is very particular with how the pieces are positioned. If a piece is in the wrong spot, he will quickly remove it from the board and re-position it in a better spot. In addition, he only uses the pieces of his opponent's colors. So far, these three rules seem fairly standard for a young wizard. However, Ralph always finds a new way to solve his problems. One day, Ralph was playing his favorite pastime chess against a new young witch. While Ralph was playing a very long game, which included many moves, he noticed that one of his opponent's pieces was no longer in the correct spot. Since he is very particular with his pieces, he quickly removed it from the board, placed it correctly, and waited to see if the witch would notice the error. At first, the witch seemed not to notice, but she quickly looked at her piece and noticed it was not in its proper spot. Then
# 793
# 0
#  There are two detectives, Detective John and Detective David. John was good friend of Detective David, and used to help him. But now John does not know what happen to Detective David. There are some suspects such as, the murderer was killed by Detective David. Then there was a murderer. The murderer was so angry and said, "you won't help me!" Now the murderer was in jail. One suspect is John. The other one is the murderer. Now the murderer was in jail. So, which suspect is innocent? John is innocent. John used to be a friend to Detective David, but now, he's not friends with him. So, David should not have been murdered by John. John must be innocent. Detective David told his story to John. John was shocked about the story. But now, John's wife is sick. She just died. John must go to his sister-in-law's funeral. After that, John will come back. John would not be able to go to the funeral of Detective David. So, John is innocent. Then there was a murderer. The murderer was angry and shouted, "I won't have help." The murderer was in jail. So the murderer could not murder anyone. There is no other suspect except John. So, John is innocent. Then there was a murderer. The murderer shouted "you
# 793
# 0
#  Heard him talking on the phone. When the car had turned around and it was safe, he had come out of the garage to get his wallet and mobile phone. He had not really thought that his wife would steal all his expensive clothes. But it was true, she had come out of the house and asked him to buy her new clothes. She had not said what kind of clothes she wanted, but had said that her present clothes were old and dirty. But she still wore them. What could he do? The thief had already taken the car and had driven away with it. The thief had put her clothes in the wardrobe, but she would get out of them again, as usual. And, as usual, she was wearing a pair of white jeans and a light-colored t-shirt with a hoodie over her head. It was so cold outside, so she did not take her jacket and hat with her. That was when the thief had stolen her car. Now she was angry. She had to get her new clothes. She did not know how she could make it up to her husband, but she would think of something when he was sleeping. She was very angry with her husband now. She tried to get some new clothes, but it was very difficult to find something that she would like. As she tried on the clothes in the changing room, it seemed to her that her husband had not looked in the wardrobe. But her husband was very patient with her. She
# 793
# 0
#  Mr. Green asked the class, "Can you identify which word in the title of this unit we will explore today?" "Ghost" said Mr. Collins. "That's right," Mr. Green said. "A ghost is a living person who's not supposed to be alive. The ghost is the person you're not supposed to see or hear. I want you to write some stories where the ghost is your character. Do you have any ideas yet?" Mr. Collins's team put out their hands in preparation for answering. Mr. Green went to each student and asked, "Is there a story that you'd like to read out loud?" "There are two stories I'd like to tell you," said Mr. Collins. "Here's one of them." Mr. Collins began reading. "When I was growing up, my father told me to be careful crossing
# 793
# 0
#  Vampire Attack The sun had just set, the sky was glowing red, and the sunbeams were falling in heavy torrents. It was a gorgeous sight, especially when the rain that had started just before had stopped, giving us a spectacular sunset. Suddenly, I heard a scream. I looked up and saw this beautiful girl that I just met, lying on the ground with one hand around her throat, and another hand on her face. I quickly ran towards her, but as I reached her I saw a strange beast rising up from the ground and coming towards me. I was so nervous that I dropped my bag, and the bag contained my iPhone 6 Plus. I ran as fast as I could, towards the phone and saw there was an alarm on. There was also some blood on my phone. I took a deep breath and turned on the alarm, then looked at the phone. It had run down to 10% battery, so I quickly called my friend. When I picked up the phone, there was a message from her saying 'Vampires are out there', 'Don't answer'. I was so scared that I couldn't see properly and got very lost and ran out of the house. When I heard a scream, I looked down and saw one of the vampires lying on the ground, and the other one with his nose in her throat.
# 793
# 1
#  As you can see, one of the most important points for your students will be that they shouldn't read anything on this topic that they are unable to understand. In order to make sure they get it, they must give your opinion about the text and you can't hide behind an opinion. You must provide a brief comment about what kind of text you've read (if you have), what points did you think were good or bad about it and explain your opinion about it. You can make use of a short anecdote, short story or some comments from a poem or something like this. Try to read this task in the way that students will be able to read it. It is difficult for them to read something they find too long and hard to understand so, it will definitely be less enjoyable for them to do it if you make it long and too difficult to read. It is also important that you provide some structure to the text. You should make use of the sentences of longer texts to make your point. For instance, the beginning of your short story should be the same as that of a longer text. If you start your story with some sentences of a longer text, it will sound better and will leave the reader with a sense that the story is a part of a whole and that there is a sequence between them. You can also combine two shorter text and create a narrative with them. If you have given your opinion about the text, provide the reason why you think it was bad
# 793
# 0
#  Zombies are always hungry, but not everyone thinks so. In some places, the zombies do not eat at all; in others, they eat only rotten or spoiled food, and in others, they kill the human beings. The most interesting zombies are slow and stupid, and the most deadly are faster and stronger. Some zombie groups are clever; others are not. Some zombies have more friends than others; others are alone and hate them for it. Some groups have a very low IQ; others are brilliant. Some are clever enough to trick people into thinking that they are not infected; others are not and can only live with them. In some places, the zombies are more intelligent than the human beings. The word "zombies" is used in many different ways. Some zombie stories are very serious and talk about people who want to escape or fight back against the zombies. These types of zombie stories also tell about how it will be difficult to survive because of the many things that can go wrong. Other zombie stories are very funny and talk about the way zombies eat human flesh. These stories also teach that there are other ways to survive other than living with zombies. Zombies are a very old and interesting concept. Many famous and many not so famous authors have written zombie stories. Here is a list of some of them, and I will give some explanations for each story.
# 793
# 0
#  Angelina Jolie and Brad Pitt are angels and they are in a difficult situation. They have to fight with each other but one day they realize they must be on good terms. They then start having lunch together and talking, they start falling in love with each other. Angelina then discovers she is pregnant with Brad's baby and Brad tells her that the baby is his and that they must stay together no matter what happens. Angelina decides to abort the baby but Brad decides not to, Angelina tells him that she loves him and asks to get married. They do and Angelina gives birth to twins, but Brad dies in a car crash. Angelina decides to give the children up but Brad begs her to keep him in her heart and to find a way to save him. Angelina goes to heaven and tells him he is in her heart and he tells her he is in her head. Angelina finds the soul of Brad and asks him to come to earth and to reunite with her and the twins. Brad does. Angelina then gives the children back to god and asks him to send a message to Brad and he does. The message says that Brad has been freed from death and they can have another happy life together. They are now free to love each other forever. They all go to heaven. Angelina says it has been a crazy day and she loves them all. The end.Angelina Jolie and Brad Pitt are angels and they are in a difficult
# 793
# 0
#  "Bewildered, a nun who was once a demon hunter asked the demon who was hiding in her body for a name. The demon refused saying that she was the one who should be bewildered. It then turned its attention to the woman who had been captured by the demons."Sister Christine, a nun, has been turned into a demon by demons. She has to hide this from the nuns and the world in general, but she knows that she is in league with Satan. The nuns suspect, but do not fully understand that she is the demon in disguise. It is obvious that Sister Christine is up to something, but they do not know what. She has been turned into a demon for a reason. The nun is now being hunted down by demons. She has been transformed by demons and they are after her. She tries to hide from them. In order to help her stay undetected, Sister Christine has been dressed in a habit with a long veil, and she is a regular nun. However, she has gained demonic powers. She does not know it. The demons, who are watching her, know what she looks like and are aware of her demonic powers. The nuns do not know either. As she continues to hide out, demons find her in a secret place, but she is able to defeat them and escape. It turns out that she is just a normal nun for the next few hours. There is a second time when Christine
# 793
# 0
#  In his opinion, as a good superhero should be able to fight with anyone. So he went to the shop and picked up some items to train. First thing he did was go back to the room and put his costume on. Then he started running. He jumped into the room and started to fight with a villain. He got a blow to the head and woke up in a hospital with a bandage on his head. So, in conclusion, be a good superhero and don't take any blow.It was a warm summer day, so I went to visit the park with my friends, one was Michael, the other was a girl called Sophie. We had the idea to make a good joke of it and put on our school uniforms. We both have a good body so we took our uniforms to our local gym. We were looking for some good equipment to train the both of us so we didn't take any equipment on that day. Later that evening, both of us were very tired so we went home. After the walk and the sleep we decided to try it again next day. We tried to do some exercises as the gym but we couldn't do it because we were so tired. When we woke up next day, Michael was still sleeping but I felt so strong and I wanted to try to do some exercises again. When I woke up, Michael was still asleep so I opened the door and I started running around the whole of the park, I jumped into the
# 793
# 0
#  The subject for today’s question is time-travel. You have been assigned the topic word “time-travelers”, which translates as a noun, and as verb. The task is to generate a short story that uses the subject word “time-travelers” in a way that is readable and is in accordance with the common core standards. Time travel is the use of the future or past to influence the present or future. This type of time travel involves traveling back in time. While this is considered to be the most difficult type of time travel, it is also the most possible. One of the most famous examples of time travel is in the movie “Back to the Future”. In order to create a story using the subject word “time-travelers”, you will have to consider three main factors. These are a title, the setting, and characters. Consider what your story will be about, then select a suitable setting. Then, consider characters and the relationships between them. Finally, create a title that will draw the reader in. The title for your story could be something like “Space Time-Travelers”. This would give the reader a clear idea that they are in the presence of time-travelers. The setting could be a space station of some sort. This place could be a small town in an unnamed planet.
# 793
# 0

# %%
report = classification_report(level_list, prediction_labels, digits=3)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#            0      0.472     0.840     0.604        50
#            1      0.273     0.060     0.098        50
#
#     accuracy                          0.450       100
#    macro avg      0.372     0.450     0.351       100
# weighted avg      0.372     0.450     0.351       100

# %%
# print distinct n
print(statistics.mean(distinct_n_scores))
print(statistics.pstdev(distinct_n_scores))
# Out:
# 0.1454259559246542
# 0.05186151006065162

# %%
def map_labels_to_numbers(labels, label_order):
    return np.array([label_order.index(label) for label in labels])

def adjacent_accuracy(y_true, y_pred):
    y_true = np.array(y_true)
    y_pred = np.array(y_pred)
    correct = np.abs(y_true - y_pred) <= 1
    return np.mean(correct)

# Define the order of your class labels
label_order = ['A2', 'B1', 'B2', 'C1', 'C2']

# Map labels to numbers
mapped_gold_standard = map_labels_to_numbers(level_list, label_order)
mapped_predicted_labels = map_labels_to_numbers(prediction_labels, label_order)

# Calculate adjacent accuracy
accuracy = adjacent_accuracy(mapped_gold_standard, mapped_predicted_labels)
print("Adjacent Accuracy:", accuracy)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-241-02d81b7d6b82> in <cell line: 14>()
#      12
#      13 # Map labels to numbers
# ---> 14 mapped_gold_standard = map_labels_to_numbers(level_list, label_order)
#      15 mapped_predicted_labels = map_labels_to_numbers(prediction_labels, label_order)
#      16
#
# <ipython-input-241-02d81b7d6b82> in map_labels_to_numbers(labels, label_order)
#       1 def map_labels_to_numbers(labels, label_order):
# ----> 2     return np.array([label_order.index(label) for label in labels])
#       3
#       4 def adjacent_accuracy(y_true, y_pred):
#       5     y_true = np.array(y_true)
#
# <ipython-input-241-02d81b7d6b82> in <listcomp>(.0)
#       1 def map_labels_to_numbers(labels, label_order):
# ----> 2     return np.array([label_order.index(label) for label in labels])
#       3
#       4 def adjacent_accuracy(y_true, y_pred):
#       5     y_true = np.array(y_true)
#
# ValueError: 0 is not in list

# %%
metric = load_metric('frugalscore.py')
frugal_dict = metric.compute(predictions = prompt_list, references = generation_list, batch_size=4, max_length=300)
frugal_scores = frugal_dict['scores']
frugal_score_mean = statistics.mean(frugal_scores)
frugal_score_std = statistics.pstdev(frugal_scores)
print("Frugalscore mean:",frugal_score_mean)
print("Frugalscore std:",frugal_score_std)

# %%
filtered_generation_list = [seq for seq in generation_list if len(seq.split()) >= 20]

# %%
perplexity_scores = []
perplexity = load("perplexity", module_type="metric")
perplexity_result = perplexity.compute(model_id='gpt2', add_start_token=False, predictions=filtered_generation_list)
perplexity_scores = perplexity_result['perplexities']

# %%
perplexity_scores = remove_outliers(perplexity_scores)
perplexity_mean = statistics.mean(perplexity_scores)
perplexity_std = statistics.pstdev(perplexity_scores)
print("Perplexity mean:",perplexity_mean)
print("Perplexity std:",perplexity_std)
